# %%
# %matplotlib inline

# %%
import sys
sys.path.append("/dat/matterhorn/akolle/dev/scripts/python")

# %%
cd /dat/matterhorn/production/portfolios/generate/CURVE_portfolios/fullsignal/NewLib20200402/FULL_SEGAB_USUKEU_fullcurvemodels_min3600max14400_semireduced_tfb20_Sh12sw500dw100_SVsignal_pwINF/
# Out:
# /dat/matterhorn/production/portfolios/generate/CURVE_portfolios/fullsignal/NewLib20200402/FULL_SEGAB_USUKEU_fullcurvemodels_min3600max14400_semireduced_tfb20_Sh12sw500dw100_SVsignal_pwINF

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [27, 24]
import simplot
simplot.calc(args_modelstr="ACC",args_sdate="20170101",args_edate="20211028",args_wfile="no",args_plot="True", args_type="SIN",args_fullstr="False",args_writewqsim="False",args_intraday="False")
# Out:
# model mean sharpe min drawdown max
# ...
# 	ACCUM_P1_WMUL25WBOUND2.0_0800_1830			 755.58	 2.97;-24752.82;-41507.46;921049.60
# PeriodPnL: 921049.60 | Mean: 755.58 | Std: 4037.95 | Sharpe: 2.97 | Sortino: 4.82 | Worst day: -24752.82(20190327) | Best day: 37758.96(20200319) | DrawDown: -41507.46 | Start,Bottom,End: 20210929,20211022,None | DrawDown/Mean: -54.93
# Daily 5% Var: -5362.50510612
# Sharpe: 2.97, Omega: 11.56, Sortino: 4.82, Kappa3: 11994.43
# PlusFreq: 0.60, Plus mean: 2998.95778908, Minus mean: -2663.55921549
# Annual Pnl Sharpe Omega:
# 2017 276543.12 5.84 26.98
# 2018 113666.30 2.46 8.63
# 2019 117635.71 1.71 5.75
# 2020 327511.76 3.76 16.34
# 2021 85692.71 1.69 5.43

# %%
cd /dat/matterhorn/production/portfolios/productionportfolio
# Out:
# /dat/matterhorn/production/portfolios/productionportfolio

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [27, 24]
import simplot
simplot.calc(args_modelstr="GLOB",args_sdate="20170101",args_edate="20211118",args_wfile="no",args_plot="True", args_type="SIN",args_fullstr="False",args_writewqsim="False",args_intraday="False")
# Out:
# model mean sharpe min drawdown max
# ...
# 	GLOBAL_LIVE_PRODUCTION_PORTFOLIO			 11718.40	 4.53;-239242.94;-313523.16;14155825.33
# PeriodPnL: 14155825.33 | Mean: 11718.40 | Std: 41082.42 | Sharpe: 4.53 | Sortino: 8.13 | Worst day: -239242.94(20210104) | Best day: 245480.40(20200312) | DrawDown: -313523.16 | Start,Bottom,End: 20200821,20200907,20200923 | DrawDown/Mean: -26.75
# Daily 5% Var: -51330.0759688
# Sharpe: 4.53, Omega: 19.79, Sortino: 8.13, Kappa3: 186023.81
# PlusFreq: 0.64, Plus mean: 33000.7424804, Minus mean: -26100.5715145
# Annual Pnl Sharpe Omega:
# 2017 2955207.80 5.50 26.94
# 2018 2766074.47 4.75 22.24
# 2019 3364606.33 6.14 30.50
# 2020 2887729.76 3.43 13.04
# 2021 2182206.98 3.80 14.60

# %%
cd /dat/matterhorn/production/portfolios/productionportfolio_SLRL/
# Out:
# /dat/matterhorn/production/portfolios/productionportfolio_SLRL

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [27, 24]
import simplot
simplot.calc(args_modelstr="GLOB",args_sdate="20170101",args_edate="20211018",args_wfile="no",args_plot="True", args_type="COMB",args_fullstr="False",args_writewqsim="False",args_intraday="False")
# Out:
# model mean sharpe min drawdown max
# ...
# 	GLOBAL_LIVE_PRODUCTION_PORTFOLIO			 1284.97	 5.28;-32783.40;-41304.19;1553529.07
# PeriodPnL: 1553529.07 | Mean: 1284.97 | Std: 3864.63 | Sharpe: 5.28 | Sortino: 10.40 | Worst day: -32783.40(20200323) | Best day: 42790.06(20200316) | DrawDown: -41304.19 | Start,Bottom,End: 20200316,20200325,20200507 | DrawDown/Mean: -32.14
# Daily 5% Var: -3832.69425141
# Sharpe: 5.28, Omega: 29.98, Sortino: 10.40, Kappa3: 20398.27
# PlusFreq: 0.68, Plus mean: 2890.7320284, Minus mean: -2136.76014617
# Annual Pnl Sharpe Omega:
# 2017 397130.24 9.80 77.12
# 2018 282227.72 4.70 25.63
# 2019 347703.57 5.87 35.84
# 2020 329881.89 4.07 22.14
# 2021 196585.65 4.17 17.78

# %%
cd /dat/matterhorn/production/portfolio/productionp
# Out:
# /dat/matterhorn/production/portfolios/generate/EU_UK_US_portfolios/StaticPortfolio20201201/whitendrift_signal/FULLEURO_SEGABC_sw5000dw500pwin5000_grid60v20210121_pwINF

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [27, 24]
import simplot
simplot.calc(args_modelstr="MUL29",args_sdate="20180101",args_edate="20220101",args_wfile="no",args_plot="True", args_type="SIN",args_fullstr="False",args_writewqsim="False",args_intraday="False")
# Out:
# model mean sharpe min drawdown max
# ...
# 	ACCUM_P1_WMUL29WBOUND2.0_0800_2130			 4187.75	 2.93;-173111.79;-367944.43;3944862.80
# 	ACCUM_P1_WMUL29WBOUND2.0_0800_2130_g360			 3813.57	 3.72;-89703.88;-124090.16;3649586.81
# PeriodPnL: 7594449.62 | Mean: 7935.68 | Std: 36260.89 | Sharpe: 3.47 | Sortino: 5.91 | Worst day: -203301.12(20210104) | Best day: 219622.27(20180529) | DrawDown: -285215.98 | Start,Bottom,End: 20200313,20200320,20200325 | DrawDown/Mean: -35.94
# Daily 5% Var: -42661.3790195
# Sharpe: 3.47, Omega: 14.14, Sortino: 5.91, Kappa3: 125975.08
# PlusFreq: 0.61, Plus mean: 27746.4694549, Minus mean: -22676.194512
# Annual Pnl Sharpe Omega:
# 2018 2102443.48 4.25 18.81
# 2019 2380445.75 4.86 20.87
# 2020 1723057.75 2.35 8.66
# 2021 1388502.64 3.16 12.36

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [27, 24]
import simplot
simplot.calc(args_modelstr="MUL29",args_sdate="20180101",args_edate="20220101",args_wfile="no",args_plot="True", args_type="SIN",args_fullstr="False",args_writewqsim="False",args_intraday="False")
# Out:
# model mean sharpe min drawdown max
# ...
# 	ACCUM_P1_WMUL29WBOUND2.0_0800_2130			 4081.51	 3.40;-113597.23;-172571.07;3673362.57
# 	ACCUM_P1_WMUL29WBOUND2.0_0800_2130_g360			 3513.45	 3.71;-89703.88;-124090.16;3214805.94
# PeriodPnL: 6888168.51 | Mean: 7528.05 | Std: 32314.46 | Sharpe: 3.70 | Sortino: 6.37 | Worst day: -203301.12(20210104) | Best day: 219622.27(20180529) | DrawDown: -270738.87 | Start,Bottom,End: 20210202,20210312,20210325 | DrawDown/Mean: -35.96
# Daily 5% Var: -41510.4631093
# Sharpe: 3.70, Omega: 14.56, Sortino: 6.37, Kappa3: 119504.14
# PlusFreq: 0.61, Plus mean: 25853.4901587, Minus mean: -20983.8701424
# Annual Pnl Sharpe Omega:
# 2018 2102443.48 4.25 18.81
# 2019 2380445.75 4.86 20.87
# 2020 1016776.64 2.32 7.53
# 2021 1388502.64 3.16 12.36

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [27, 24]
import simplot
simplot.calc(args_modelstr="ACC",args_sdate="20170101",args_edate="20220101",args_wfile="no",args_plot="True", args_type="SIN",args_fullstr="False",args_writewqsim="False",args_intraday="False")
# Out:
# model mean sharpe min drawdown max
# ...
# 	ACCUM_P1_WMUL21WBOUND2.0_0800_1400			 3054.05	 4.55;-78205.63;-93723.42;3597673.97
# 	ACCUM_P1_WMUL21WBOUND2.0_0800_1400_prod			 2779.14	 4.07;-93429.65;-124471.02;3273832.20
# PeriodPnL: 6871506.17 | Mean: 5833.20 | Std: 20618.01 | Sharpe: 4.49 | Sortino: 7.76 | Worst day: -171635.28(20200323) | Best day: 157179.94(20200319) | DrawDown: -218194.44 | Start,Bottom,End: 20200318,20200323,20200429 | DrawDown/Mean: -37.41
# Daily 5% Var: -22560.2360743
# Sharpe: 4.49, Omega: 21.55, Sortino: 7.76, Kappa3: 92599.13
# PlusFreq: 0.66, Plus mean: 15319.1318782, Minus mean: -12718.8380955
# Annual Pnl Sharpe Omega:
# 2017 1297158.65 5.69 25.81
# 2018 1384434.94 4.89 22.05
# 2019 1649672.80 4.34 21.86
# 2020 1495858.81 3.67 17.55
# 2021 1044380.96 5.22 23.15

# %%
cd /dat/matterhorn/production/portfolios/generate/SLRL_portfolios/current_libs20210616/slrl_StaticModels_SegmentABC08002130_SV_SegmentVola_mpf60_MarchRemoval_pwINF
# Out:
# /dat/matterhorn/production/portfolios/generate/SLRL_portfolios/current_libs20210616/slrl_StaticModels_SegmentABC08002130_SV_SegmentVola_mpf60_MarchRemoval_pwINF

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [27, 24]
import simplot
simplot.calc(args_modelstr="ACC",args_sdate="20170101",args_edate="20210925",args_plot="True", args_type="SIN",args_fullstr="False",args_writewqsim="False",args_intraday="False")
# Out:
# model mean sharpe min drawdown max
# ...
# 	ACCUM_P1_WMUL19WBOUND2.0_0800_2130			 2741.24	 4.29;-65521.45;-131716.02;3229177.39
# 	ACCUM_P1_WMUL19WBOUND2.0_0800_2130ProdSetting		 2482.14	 3.40;-110579.12;-254137.59;2923960.83
# PeriodPnL: 6153138.22 | Mean: 5223.38 | Std: 20978.68 | Sharpe: 3.95 | Sortino: 6.89 | Worst day: -176100.58(20200319) | Best day: 209628.05(20200316) | DrawDown: -383989.62 | Start,Bottom,End: 20200313,20200320,20200709 | DrawDown/Mean: -73.51
# Daily 5% Var: -24284.4157954
# Sharpe: 3.95, Omega: 18.99, Sortino: 6.89, Kappa3: 82918.54
# PlusFreq: 0.64, Plus mean: 14923.5858213, Minus mean: -12276.888427
# Annual Pnl Sharpe Omega:
# 2017 1733617.47 6.66 37.51
# 2018 1327985.48 4.40 23.42
# 2019 1579284.35 6.15 36.95
# 2020 789776.98 1.70 6.90
# 2021 722473.94 3.12 11.30

# %%
cd /dat/matterhorn/production/portfolios/generate/CAD_US_portfolios/fullsignal/NewLibrary20200505/SEGBC_USCAD__dailytfb20_Sh10sw500dw250_pwin500_grid240_RemoveMarch_SV_hedged_pwINF
# Out:
# /dat/matterhorn/production/portfolios/generate/CAD_US_portfolios/fullsignal/NewLibrary20200505/SEGBC_USCAD__dailytfb20_Sh10sw500dw250_pwin500_grid240_RemoveMarch_SV_hedged_pwINF

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [27, 24]
import simplot
simplot.calc(args_modelstr="ACC",args_sdate="20170101",args_edate="20211109",args_wfile="wfile",args_plot="True", args_type="SIN",args_fullstr="False",args_writewqsim="False",args_intraday="False")
# Out:
# model mean sharpe min drawdown max
# ...
# 	ACCUM_P1_WMUL15WBOUND2.0_1230_2130			 1712.22	 4.02;-30616.30;-50552.27;1975900.60
# 	ACCUM_P1_WMUL15WBOUND2.0_1230_2130_prod			 1644.50	 4.02;-32981.66;-54889.02;1897747.82
# PeriodPnL: 3873648.42 | Mean: 3356.71 | Std: 12514.39 | Sharpe: 4.26 | Sortino: 9.13 | Worst day: -54047.90(20200327) | Best day: 102188.80(20170906) | DrawDown: -89893.22 | Start,Bottom,End: 20170424,20170502,20170719 | DrawDown/Mean: -26.78
# Daily 5% Var: -12766.3739767
# Sharpe: 4.26, Omega: 24.31, Sortino: 9.13, Kappa3: 53286.19
# PlusFreq: 0.66, Plus mean: 8436.17868956, Minus mean: -6419.82539765
# Annual Pnl Sharpe Omega:
# 2017 1108281.55 4.88 34.02
# 2018 769163.51 3.45 17.95
# 2019 879383.61 4.99 29.92
# 2020 592452.19 4.03 18.53
# 2021 524367.55 4.20 23.26

# %%
cd /dat/matterhorn/production/portfolios/productionportfolio_CAD
# Out:
# /dat/matterhorn/production/portfolios/productionportfolio_CAD

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [27, 24]
import simplot
simplot.calc(args_modelstr="GLOB",args_sdate="20210101",args_edate="20221011",args_wfile="no",args_plot="True", args_type="COMB",args_fullstr="False",args_writewqsim="False",args_intraday="False")
# Out:
# model mean sharpe min drawdown max
# ...
# 	GLOBAL_LIVE_PRODUCTION_PORTFOLIO			 254.54	 2.10;-8507.22;-13463.35;46326.63
# PeriodPnL: 46326.63 | Mean: 254.54 | Std: 1920.56 | Sharpe: 2.10 | Sortino: 3.89 | Worst day: -8507.22(20210922) | Best day: 9342.07(20210421) | DrawDown: -13463.35 | Start,Bottom,End: 20210914,20210924,None | DrawDown/Mean: -52.89
# Daily 5% Var: -1919.78062897
# Sharpe: 2.10, Omega: 10.90, Sortino: 3.89, Kappa3: 4040.73
# PlusFreq: 0.50, Plus mean: 1250.25334311, Minus mean: -793.487301733
# Annual Pnl Sharpe Omega:
# 2021 46326.63 2.10 10.90

# %%
cd /dat/matterhorn/production/portfolios/generate/SLRL_portfolios/current_libs20210616/slrl_StaticModels_SegmentABC08002130_SV_SegmentVola_mpf60_MarchRemoval_sw5000dw100mpw5000pw100
# Out:
# /dat/matterhorn/production/portfolios/generate/SLRL_portfolios/current_libs20210616/slrl_StaticModels_SegmentABC08002130_SV_SegmentVola_mpf60_MarchRemoval_sw5000dw100mpw5000pw100

# %%
import simplot
simplot.calc(args_modelstr="ACC",args_sdate="20170101",args_edate="20210928",args_wfile="no",args_plot="True", args_type="SIN")
# Out:
# model mean sharpe min drawdown max
# ...
# 	ACCUM_P1_WMUL19WBOUND2.0_0800_2130			 2538.00	 3.74;-61258.80;-177078.51;3015141.09
# 	ACCUM_P1_WMUL19WBOUND2.0_0800_2130_pwINF		 2766.46	 4.33;-65521.45;-131716.02;3286557.37
# PeriodPnL: 6301698.45 | Mean: 5304.46 | Std: 20140.08 | Sharpe: 4.18 | Sortino: 7.44 | Worst day: -126780.26(20200319) | Best day: 196418.94(20200316) | DrawDown: -306930.54 | Start,Bottom,End: 20200313,20200320,20200626 | DrawDown/Mean: -57.86
# Daily 5% Var: -25052.4145887
# Sharpe: 4.18, Omega: 19.07, Sortino: 7.44, Kappa3: 84205.69
# PlusFreq: 0.65, Plus mean: 14936.8517468, Minus mean: -12698.5180298
# Annual Pnl Sharpe Omega:
# 2017 1674707.44 6.34 33.53
# 2018 1354012.91 4.36 22.60
# 2019 1690241.74 6.10 32.25
# 2020 840516.90 2.07 8.13
# 2021 742219.46 3.21 11.46

# %%
cd /dat/matterhorn/production/portfolios/generate/PWINF/SEGABC_LowSharpeModels_dailytfb20_pw5000sw5000dw5000grid240/
# Out:
# /dat/matterhorn/production/portfolios/generate/PWINF/SEGABC_LowSharpeModels_dailytfb20_pw5000sw5000dw5000grid240

# %%
import simplot
simplot.calc(args_modelstr="ACC",args_sdate="20170101",args_edate="20221008",args_wfile="no",args_plot="True", args_type="SIN")
# Out:
# model mean sharpe min drawdown max
# ...
# 	ACCUM_P1_WMUL19WBOUND2.0_0800_2130			 2492.36	 2.66;-72795.57;-171934.32;2953446.79
# PeriodPnL: 2953446.79 | Mean: 2492.36 | Std: 14861.48 | Sharpe: 2.66 | Sortino: 5.43 | Worst day: -72795.57(20210706) | Best day: 181618.78(20200317) | DrawDown: -171934.32 | Start,Bottom,End: 20210610,20210707,None | DrawDown/Mean: -68.98
# Daily 5% Var: -14118.55321
# Sharpe: 2.66, Omega: 13.24, Sortino: 5.43, Kappa3: 39564.99
# PlusFreq: 0.59, Plus mean: 9238.03416917, Minus mean: -7346.24737302
# Annual Pnl Sharpe Omega:
# 2017 420655.01 2.97 11.24
# 2018 262311.51 1.90 6.08
# 2019 495289.82 3.29 13.11
# 2020 1665760.23 4.28 33.72
# 2021 109430.22 0.62 1.98

# %%
cd /dat/matterhorn/production/portfolios/generate/CAD_US_portfolios/fullsignal/NewLibrary20200505/SEGBC_USCAD_dailytfb50_NoCurve1230_sq3/
# Out:
# /dat/matterhorn/production/portfolios/generate/CAD_US_portfolios/fullsignal/NewLibrary20200505/SEGBC_USCAD_dailytfb50_NoCurve1230_sq3

# %%
import simplot
simplot.calc(args_modelstr="prod",args_sdate="20180101",args_edate="20200515",args_wfile="no",args_plot="True", args_type="SIN")
# Out:
# model mean sharpe min drawdown max
# ...
# 	ACCUM_P1_WMUL75WBOUND2.0_1230_2130_prod			 4580.65	 3.18;-136246.41;-186783.77;2665939.18
# 	ACCUM_P1_WMUL75WBOUND2.0_1230_2130_prodold		 4032.33	 2.61;-158804.44;-178136.72;2282296.26
# 	ACCUM_P1_WMUL75WBOUND2.0_1230_2130_prodsq10		 4580.65	 3.18;-136246.41;-186783.77;2665939.18
# PeriodPnL: 7614174.63 | Mean: 13082.77 | Std: 67276.43 | Sharpe: 3.09 | Sortino: 5.01 | Worst day: -431297.27(20200327) | Best day: 531409.19(20200303) | DrawDown: -516948.30 | Start,Bottom,End: 20180327,20180516,20180611 | DrawDown/Mean: -39.51
# Daily 5% Var: -86839.4466967
# Sharpe: 3.09, Omega: 13.09, Sortino: 5.01, Kappa3: 207682.60
# PlusFreq: 0.65, Plus mean: 44449.0706557, Minus mean: -45477.9465468
# Annual Pnl Sharpe Omega:
# 2018 1556570.39 1.61 5.54
# 2019 4253867.21 4.90 22.40
# 2020 1803737.02 3.13 16.27
# Monthly Plus Freq: 72.41

# %%
cd /dat/matterhorn/production/portfolios/generate/EU_UK_US_portfolios/fullsignal/20200203_NewSimulations/FullMigration20200225/NewLib20200305/FULLEURO_SEGA_Prod2015Settings_dailytfb20_NoYM_NoZ_noZB_nosw_daysremoval_min7200/
# Out:
# /dat/matterhorn/production/portfolios/generate/EU_UK_US_portfolios/fullsignal/20200203_NewSimulations/FullMigration20200225/NewLib20200305/FULLEURO_SEGA_Prod2015Settings_dailytfb20_NoYM_NoZ_noZB_nosw_daysremoval_min7200

# %%
import simplot
simplot.calc(args_modelstr="ACCUM_P1_WMUL10WBOUND2.0_0830_1400",args_sdate="20150101",args_edate="20200915",args_wfile="wfile",args_plot="True", args_type="SIN")
# Out:
# model mean sharpe min drawdown max
# ...
# 	ACCUM_P1_WMUL10WBOUND2.0_0830_1400			 629.45	 2.97;-31207.05;-41003.31;901369.86
# PeriodPnL: 901369.86 | Mean: 629.45 | Std: 3369.78 | Sharpe: 2.97 | Sortino: 4.84 | Worst day: -31207.05(20200320) | Best day: 25266.86(20200309) | DrawDown: -41003.31 | Start,Bottom,End: 20200317,20200320,20200813 | DrawDown/Mean: -65.14
# Daily 5% Var: -3738.25377682
# Sharpe: 2.97, Omega: 13.33, Sortino: 4.84, Kappa3: 9992.18
# PlusFreq: 0.61, Plus mean: 2278.09523144, Minus mean: -1931.18472688
# Annual Pnl Sharpe Omega:

# %%
cd /dat/matterhorn/production/portfolios/productionportfolio/
# Out:
# /dat/matterhorn/production/portfolios/productionportfolio

# %%
import simplot
simplot.calc(args_modelstr="40mAUM",args_sdate="20170107",args_edate="20211005",args_wfile="no",args_plot="True", args_type="SIN")
# Out:
# model mean sharpe min drawdown max
# ...
# 	MULTIPORTFOLIO_ACCUM_OOS_StaticGM_40mAUM		 17992.42	 4.53;-352104.53;-402079.77;19845635.30
# 	MULTIPORTFOLIO_ACCUM_OOS_StaticGM_40mAUM_rty		 17795.86	 4.72;-336617.59;-401814.82;19628831.51
# PeriodPnL: 39474466.81 | Mean: 35788.27 | Std: 121983.03 | Sharpe: 4.66 | Sortino: 9.76 | Worst day: -688722.11(20200320) | Best day: 1448691.40(20200312) | DrawDown: -803894.60 | Start,Bottom,End: 20200317,20200320,20200324 | DrawDown/Mean: -22.46
# Daily 5% Var: -110322.825118
# Sharpe: 4.66, Omega: 26.64, Sortino: 9.76, Kappa3: 568121.25
# PlusFreq: 0.65, Plus mean: 87622.2714175, Minus mean: -61265.4852659
# Annual Pnl Sharpe Omega:
# 2017 9094842.46 6.65 35.39
# 2018 7432762.69 5.53 26.56
# 2019 10527434.88 6.20 35.33
# 2020 10396930.67 3.46 20.22
# 2021 2022496.11 3.71 15.20
# Monthly Plus Freq: 94.34

# %%
cd /dat/matterhorn/production/portfolios/generate/SLRL_portfolios/SV_models_21210329/slrl_models_SegmentA08001400_noISOS_full_SV_AfterLibRerun
# Out:
# /dat/matterhorn/production/portfolios/generate/SLRL_portfolios/SV_models_21210329/slrl_models_SegmentA08001400_noISOS_full_SV_AfterLibRerun

# %%
import simplot
simplot.calc(args_modelstr="ACCUM_P1_WMUL14WBOUND2.0_0800_1400_specialdays",args_sdate="20170101",args_edate="20210507",args_wfile="no",args_plot="True", args_type="SIN")
# Out:
# model mean sharpe min drawdown max
# ...
# 	ACCUM_P1_WMUL14WBOUND2.0_0800_1400_specialdays		 1984.77	 4.02;-73633.47;-126290.64;2171341.94
# 	ACCUM_P1_WMUL14WBOUND2.0_0800_1400_specialdays_statsettings 1759.82	 4.04;-80746.69;-129107.27;1925240.71
# PeriodPnL: 4096582.65 | Mean: 3744.59 | Std: 14047.44 | Sharpe: 4.23 | Sortino: 7.79 | Worst day: -154380.16(20200323) | Best day: 158942.27(20200316) | DrawDown: -255397.91 | Start,Bottom,End: 20200318,20200325,20200612 | DrawDown/Mean: -68.20
# Daily 5% Var: -13212.1058342
# Sharpe: 4.23, Omega: 23.04, Sortino: 7.79, Kappa3: 59443.54
# PlusFreq: 0.64, Plus mean: 9885.03021923, Minus mean: -7238.30385529
# Annual Pnl Sharpe Omega:
# 2017 817418.67 5.53 25.02
# 2018 850013.94 5.15 23.94
# 2019 1074550.23 5.15 28.80
# 2020 1012211.96 3.01 17.02
# 2021 342387.86 5.69 26.64
# Monthly Plus Freq: 96.23
